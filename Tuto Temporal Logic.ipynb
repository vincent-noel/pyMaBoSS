# %% [markdown]
# # How to use the temporal logic ?
# First import all that is needed as below :

# %%
import sys
import os
import maboss
from maboss import temporal_logic as tl
# Out:
# ipylab module is not installed, menus and toolbar are disabled.

# %% [markdown]
# # Step 1 - Run a simulation

# %%
BRAF_model = maboss.load("BRAF_Model.bnd", "BRAF_Model.cfg")
wt_res = BRAF_model.run()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 BRAF_model = maboss.load("BRAF_Model.bnd", "BRAF_Model.cfg")
#       2 wt_res = BRAF_model.run()
#
# File ~/Documents/MaBoSS/pyMaBoSS/maboss/gsparser.py:179, in load(bnd_filename, *cfg_filenames, **extra_args)
#     176 command = extra_args.get("command")
#     178 with ExitStack() as stack:
# --> 179     bnd_file = stack.enter_context(open(bnd_filename, 'r'))
#     180     bnd_content = bnd_file.read()
#     182     cfg_content = ""
#
# FileNotFoundError: [Errno 2] No such file or directory: 'BRAF_Model.bnd'

# %%
# %ls
# Out:
#  MANIFEST.in                  doc/
#  README.md                    maboss/
# 'Tuto Temporal Logic.ipynb'   maboss.egg-info/
#  __pycache__/                 maboss_setup.py
#  compute_intrication.csv      maboss_setup_experimental.py
#  compute_with_or.csv          notebook/
#  compute_with_or_not.csv      scripts/
#  conda/                       setup.py
#  description.rst              test/
