# %%
# %load_ext autoreload
# %autoreload 2

    import
# Out:
# ipylab module is not installed, menus and toolbar are disabled.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import maboss
#       2 import sys
#       3 bndfile = sys.path.append("./test/Four_cycle.bnd")
#       4 cfgfile = sys.path.append("./test/Four_cycle_FEscape.cfg")
#
# File ~/Documents/MaBoSS/pyMaBoSS/maboss/__init__.py:18
#      16 if IN_IPYTHON:
#      17     from colomoto_jupyter import jupyter_setup
# ---> 18     from .widgets import *
#      20     import matplotlib.pyplot as plt
#      21     plt.ion()
#
# File ~/Documents/MaBoSS/pyMaBoSS/maboss/widgets/__init__.py:1
# ----> 1 from .ipywidgets import *
#       2 from .menu import menu, toolbar, js_api
#
# File ~/Documents/MaBoSS/pyMaBoSS/maboss/widgets/ipywidgets.py:2
# ----> 2 import ipywidgets as widgets
# ...
