# %% [markdown]
# # Ensemble MaBoSS simulations

# %%
import maboss, time, pandas, numpy, multiprocessing
# Out:
# <script type="text/javascript" id="colomoto-setup-8266294" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
# function detect_import(cell, module) {
#     var code = cell.get_text();
#     code = code.replace(/\\\n/g, "");
#     var lines = code.split("\n");
#     var r_simple = new RegExp("^("+module+")$");
#     var r_alias = new RegExp("^"+module+"\\s+as\\s+(\\w+)$");
#     for (var i = 0; i < lines.length; ++i) {
#         if (/^import\s/.test(lines[i])) {
#             code = lines[i].substr(7);
#             var parts = code.split(",")
#             for (var j = 0; j < parts.length; ++j) {
#                 code = parts[j].trim();
#                 var m = code.match(r_simple);
#                 if (!m) {
#                     m = code.match(r_alias);
#                 }
#                 if (m) {
#                     return m[1];
#                 }
#             }
#         }
#     }
#     return module;
# }
#
# ...

# %% [markdown]
# ## Simulating the ensemble

# %%
t0 = time.time()

simulation = maboss.Ensemble(
    path="Invasion",
    use_physrandgen=0, 
    sample_count=100000, 
    thread_count=6,
    max_time=50, time_tick=1,
    discrete_time=1,
    outputs=['Apoptosis', 'CellCycleArrest', 'Invasion'],
    random_sampling=True
)

result = simulation.run()

print("Simulation executed in %.2fs" % (time.time() - t0))
# Out:
# Simulation executed in 8.77s

# %%
result.plot_piechart()

# %%
result.plot_trajectory()

# %% [markdown]
# ## Simulating the ensemble, keeping individual results to be analyzed

# %%
t0 = time.time()

simulation = maboss.Ensemble(
    path="Invasion",
    use_physrandgen=0, 
    sample_count=100000,
    thread_count=6,
    max_time=50, time_tick=1,
    outputs=['Apoptosis', 'CellCycleArrest', 'Invasion'],
    individual_results=True,
    random_sampling=True
)

result = simulation.run()

print("Simulation executed in %.2fs" % (time.time() - t0))
# Out:
# Simulation executed in 12.19s

# %%
result.plotSteadyStatesDistribution(figsize=(20, 10))

# %%
result.plotSteadyStatesNodesDistribution(figsize=(20, 10))
